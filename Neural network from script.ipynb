# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Sep  7 18:35:34 2021

This code refers to:
https://machinelearningmastery.com/implement-backpropagation-algorithm-scratch-python/
http://neuralnetworksanddeeplearning.com/chap1.html


@author: Ziyang Xie
"""
from random import randrange
from math import exp
from random import seed
from random import random
import numpy as np
import matplotlib.pyplot as plt
import collections

# %%
'''
For the simplest case, we create one hidden layer. This hidden layer has n_hidden neurons, 
and each neurons has n_inputs + 1 (1 for bias) weights. Similarly, each output neuron has n_hidden + 1 weights.
'''
def init_network(n_inputs, n_hidden, n_outputs):
    network = []
    hidden_layer = [{'weights': [random() for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer)
    output_layer = [{'weights': [random() for i in range(n_hidden + 1)]} for i in range(n_outputs)]
    network.append(output_layer)
    return network

# %%
'''
Based on this equation: activation = sum(weight_i * input_i) + bias
Quite simple!
'''
def activate(weights, inputs):
    activation = weights[-1]
    for i in range(len(weights) - 1):#last element is the bias
        activation += weights[i] * inputs[i]
    return activation

# %%
'''
We use sigmoid activation here. 
Commonly-used activation functions:
https://towardsdatascience.com/activation-functions-neural-networks-1cbd9f8d91d6
'''
def transfer(activation):
    return 1.0 / (1.0 + exp(-activation))

# %%
'''
for each layer, it receives previous layer's outputs as input, and calculates it's output by activation / tranfer function. Thin function returns the ouputs from the last layer (output layer)
'''
def forward_propagate(network, row):
    inputs = row
    for layer in network:
        new_inputs = []
        for neuron in layer:
            activation = activate(neuron['weights'], inputs)
            neuron['output'] = transfer(activation)
            new_inputs.append(neuron['output'])
        inputs = new_inputs
    return inputs

# %%
'''
Now it comes to the backpropagation , we first need to calculate the derivative of sigmoid transfer funtion.
'''
def transfer_derivative(output):
	return output * (1.0 - output)

# %%
'''
We first calculate the error signal from each neuron and save it with the name delta.
Please note that in the last layer, the error is (expected value of the output - output of the output layer). Then, the error signal propagage back to the previous layers by
	
error = (weight_k * error_j) * transfer_derivative(output)

Where error_j is the error signal from the jth neuron in the output layer, weight_k is the weight that connects the kth neuron to the current neuron and output is the output for the current neuron.
'''
def backward_propagate_error(network, expected):
    for i in range(len(network) - 1, -1, -1):#reverse range
        layer = network[i]
        errors = []
        if i != len(network) - 1:
            for j in range(len(layer)):
                error = 0.0
                for neuron in network[i + 1]:
                    error += (neuron['weights'][j] * neuron['delta'])
                errors.append(error)
        else:
            for j in range(len(layer)):
                neuron = layer[j]
                errors.append(expected[j] - neuron['output'])
        for j in range(len(layer)):
            neuron = layer[j]
            neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])

# %%
'''
After the errors are calculated for each neuron, we can use these errors to update weights:
    	
weight = weight + learning_rate * error * input

Where weight is a given weight, learning_rate is a parameter that you must specify, error is the error calculated by the backpropagation procedure for the neuron and input is the input value that caused the error.

'''
def update_weights(network, row, l_rate):
    for i in range(len(network)):
        inputs = row[:-1]
        if i != 0:
            inputs = [neuron['output'] for neuron in network[i - 1]]
        for neuron in network[i]:
            for j in range(len(inputs)):
                neuron['weights'][j] += l_rate * neuron['delta'] * inputs[j]
            neuron['weights'][-1] += l_rate * neuron['delta'] #update the weights of bias

# %%
'''
Here, the network is updated using stochastic gradiant descent (online gradiant descent), This is because updates are made for each pattern, If errors were accumulated across an epoch before updating the weights, this is called batch learning or batch gradient descent (which is commonly used in large-scale networks and need a batch size parameter).

The sum squared error between the expected output and the network output is accumulated each epoch and printed. This is helpful to create a trace of how much the network is learning and improving each epoch.
'''
def train(network, train, l_rate, n_epoch, n_outputs):
    for epoch in range(n_epoch):
        sum_error = 0
        for row in train:
            outputs = forward_propagate(network, row)
            expected = [0 for i in range(n_outputs)]
            expected[row[-1]] = 1
            sum_error += sum([(expected[i] - outputs[i]) ** 2 for i in range(len(expected))])
            backward_propagate_error(network, expected)
            update_weights(network, row, l_rate)
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))

# %%
'''
Using this plot function, you can see the distribution of two data sets
'''

def plot_data(dataset,color = 'r'):
    d = collections.defaultdict(list)
    for x, y, data_type in dataset:
        d[data_type].append([x,y])
    for key in d.keys():
        data = np.transpose(np.array(d[key]))
        plt.scatter(data[0],data[1], label = key)
    plt.legend()

# %%
'''
In general, it is good to normalize input values to the range of transfer function (our sigmoid funciton ranges between 0 and 1). Therefore, we need a helper function to normalize the input.
'''
def normalize_dataset(dataset):
    stats = [[min(column), max(column)] for column in zip(*dataset)]
    for row in dataset:
            for i in range(len(row)-1):
                row[i] = (row[i] - stats[i][0]) / (stats[i][1] - stats[i][0])

# %%
'''
Apply k-folds cross validation. Cross-validation is primarily used in applied machine learning to estimate the skill of a machine learning model on unseen data
For more details:
https://machinelearningmastery.com/k-fold-cross-validation/
'''
def cross_validation_split(dataset, n_folds):
    dataset_split = list()
    dataset_copy = list(dataset)
    fold_size = int(len(dataset) / n_folds)
    for i in range(n_folds):
        fold = list()
        while len(fold) < fold_size:
            index = randrange(len(dataset_copy))
            fold.append(dataset_copy.pop(index))
        dataset_split.append(fold)
    return dataset_split

# %%
'''
Calculate accuracy percentage
'''
def accuracy_metric(actual, predicted):
    correct = 0
    for i in range(len(actual)):
        if actual[i] == predicted[i]:
            correct += 1
    return correct / float(len(actual)) * 100.0

# %%
'''
Evaluate algorithm using cross validation split
'''
def evaluate_algorithm(dataset, algorithm, n_folds, *args):
    folds = cross_validation_split(dataset, n_folds)
    scores = list()
    for fold in folds:
        train_set = list(folds)
        train_set.remove(fold)
        train_set = sum(train_set, [])
        test_set = list()
        for row in fold:
            row_copy = list(row)
            test_set.append(row_copy)
            row_copy[-1] = None
        predicted = algorithm(train_set, test_set, *args)
        actual = [row[-1] for row in fold]
        accuracy = accuracy_metric(actual, predicted)
        scores.append(accuracy)
    return scores

# %%
'''
Make predictions
'''
def predict(network, row):
    outputs = forward_propagate(network, row)
    return outputs.index(max(outputs))

# %%
'''
Create a toy dataset (change these parameters and see how our network performs), and do a pilot test.
'''
seed(1)
x1_base, y1_base, x2_base, y2_base = 0, 0, 2, 2
x1_rand, y1_rand, x2_rand, y2_rand = 4, 4, 4, 4
type_1data = [[x1_base + (random() - 0.5) * x1_rand, y1_base + (random() - 0.5) * y1_rand, 0] for _ in range(100)]
type_2data = [[x2_base + (random() - 0.5) * x2_rand, y2_base + (random() - 0.5) * y2_rand, 1] for _ in range(100)]
dataset =  type_1data + type_2data
plot_data(dataset)

# %%
n_inputs = len(dataset[0]) - 1
n_outputs = len(set([row[-1] for row in dataset]))
network = init_network(n_inputs, 5, n_outputs)
train(network, dataset, 0.05, 30, n_outputs)
minmax = normalize_dataset(dataset)
# Out:
# >epoch=0, lrate=0.050, error=157.474
# >epoch=1, lrate=0.050, error=142.946
# >epoch=2, lrate=0.050, error=136.875
# >epoch=3, lrate=0.050, error=126.977
# >epoch=4, lrate=0.050, error=87.684
# >epoch=5, lrate=0.050, error=73.057
# >epoch=6, lrate=0.050, error=72.130
# >epoch=7, lrate=0.050, error=68.360
# >epoch=8, lrate=0.050, error=64.099
# >epoch=9, lrate=0.050, error=59.958
# >epoch=10, lrate=0.050, error=56.245
# >epoch=11, lrate=0.050, error=53.089
# >epoch=12, lrate=0.050, error=50.472
# >epoch=13, lrate=0.050, error=48.318
# >epoch=14, lrate=0.050, error=46.544
# >epoch=15, lrate=0.050, error=45.077
# >epoch=16, lrate=0.050, error=43.859
# >epoch=17, lrate=0.050, error=42.842
# >epoch=18, lrate=0.050, error=41.990
# >epoch=19, lrate=0.050, error=41.273
# >epoch=20, lrate=0.050, error=40.668
# >epoch=21, lrate=0.050, error=40.154
# >epoch=22, lrate=0.050, error=39.718
# >epoch=23, lrate=0.050, error=39.345
# >epoch=24, lrate=0.050, error=39.026
# >epoch=25, lrate=0.050, error=38.752
# >epoch=26, lrate=0.050, error=38.515
# >epoch=27, lrate=0.050, error=38.311
# >epoch=28, lrate=0.050, error=38.133
# >epoch=29, lrate=0.050, error=37.979

# %%
for row in dataset:
    prediction = predict(network, row)
    print('Expected=%d, Got=%d' % (row[-1], prediction))
# Out:
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=1
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=1
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=1
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=0
# Expected=1, Got=0
# Expected=1, Got=1

# %%
'''
Use normalization and k-fold to evaluate our model's performance on toy data
'''
def back_propagation(train_data, test, l_rate, n_epoch, n_hidden):
    n_inputs = len(train_data[0]) - 1
    n_outpus = len(set(row[-1] for row in train_data))
    network = init_network(n_inputs, n_hidden, n_outputs)
    train(network, train_data, l_rate, n_epoch, n_outputs)
    predictions = list()
    for row in test:
        prediction = predict(network, row)
        predictions.append(prediction)
    return(predictions)

normalize_dataset(dataset)
# evaluate algorithm
n_folds = 5
l_rate = 0.3
n_epoch = 500
n_hidden = 5
scores = evaluate_algorithm(dataset, back_propagation, n_folds, l_rate, n_epoch, n_hidden)
print('Scores: %s' % scores)
print('Mean Accuracy: %.3f%%' % (sum(scores)/float(len(scores))))
# Out:
# >epoch=0, lrate=0.300, error=92.064
# >epoch=1, lrate=0.300, error=79.963
# >epoch=2, lrate=0.300, error=77.697
# >epoch=3, lrate=0.300, error=74.470
# >epoch=4, lrate=0.300, error=69.937
# >epoch=5, lrate=0.300, error=64.086
# >epoch=6, lrate=0.300, error=57.536
# >epoch=7, lrate=0.300, error=51.351
# >epoch=8, lrate=0.300, error=46.340
# >epoch=9, lrate=0.300, error=42.696
# >epoch=10, lrate=0.300, error=40.200
# >epoch=11, lrate=0.300, error=38.526
# >epoch=12, lrate=0.300, error=37.396
# >epoch=13, lrate=0.300, error=36.621
# >epoch=14, lrate=0.300, error=36.078
# >epoch=15, lrate=0.300, error=35.690
# >epoch=16, lrate=0.300, error=35.409
# >epoch=17, lrate=0.300, error=35.202
# >epoch=18, lrate=0.300, error=35.047
# >epoch=19, lrate=0.300, error=34.931
# >epoch=20, lrate=0.300, error=34.843
# >epoch=21, lrate=0.300, error=34.776
# >epoch=22, lrate=0.300, error=34.723
# >epoch=23, lrate=0.300, error=34.683
# >epoch=24, lrate=0.300, error=34.651
# >epoch=25, lrate=0.300, error=34.626
# >epoch=26, lrate=0.300, error=34.606
# >epoch=27, lrate=0.300, error=34.590
# >epoch=28, lrate=0.300, error=34.577
# >epoch=29, lrate=0.300, error=34.566
# >epoch=30, lrate=0.300, error=34.556
# >epoch=31, lrate=0.300, error=34.548
# >epoch=32, lrate=0.300, error=34.541
# >epoch=33, lrate=0.300, error=34.534
# >epoch=34, lrate=0.300, error=34.528
# >epoch=35, lrate=0.300, error=34.521
# >epoch=36, lrate=0.300, error=34.515
# >epoch=37, lrate=0.300, error=34.509
# >epoch=38, lrate=0.300, error=34.503
# >epoch=39, lrate=0.300, error=34.496
# >epoch=40, lrate=0.300, error=34.490
# >epoch=41, lrate=0.300, error=34.483
# >epoch=42, lrate=0.300, error=34.476
# >epoch=43, lrate=0.300, error=34.469
# >epoch=44, lrate=0.300, error=34.461
# >epoch=45, lrate=0.300, error=34.454
# >epoch=46, lrate=0.300, error=34.446
# >epoch=47, lrate=0.300, error=34.437
# >epoch=48, lrate=0.300, error=34.429
# >epoch=49, lrate=0.300, error=34.420
# >epoch=50, lrate=0.300, error=34.411
# >epoch=51, lrate=0.300, error=34.403
# >epoch=52, lrate=0.300, error=34.393
# >epoch=53, lrate=0.300, error=34.384
# >epoch=54, lrate=0.300, error=34.375
# >epoch=55, lrate=0.300, error=34.366
# >epoch=56, lrate=0.300, error=34.356
# >epoch=57, lrate=0.300, error=34.347
# >epoch=58, lrate=0.300, error=34.338
# >epoch=59, lrate=0.300, error=34.328
# >epoch=60, lrate=0.300, error=34.319
# >epoch=61, lrate=0.300, error=34.310
# >epoch=62, lrate=0.300, error=34.301
# >epoch=63, lrate=0.300, error=34.292
# >epoch=64, lrate=0.300, error=34.283
# >epoch=65, lrate=0.300, error=34.274
# >epoch=66, lrate=0.300, error=34.266
# >epoch=67, lrate=0.300, error=34.257
# >epoch=68, lrate=0.300, error=34.249
# >epoch=69, lrate=0.300, error=34.241
# >epoch=70, lrate=0.300, error=34.233
# >epoch=71, lrate=0.300, error=34.226
# >epoch=72, lrate=0.300, error=34.218
# >epoch=73, lrate=0.300, error=34.211
# >epoch=74, lrate=0.300, error=34.203
# >epoch=75, lrate=0.300, error=34.196
# >epoch=76, lrate=0.300, error=34.189
# >epoch=77, lrate=0.300, error=34.182
# >epoch=78, lrate=0.300, error=34.176
# >epoch=79, lrate=0.300, error=34.169
# >epoch=80, lrate=0.300, error=34.163
# >epoch=81, lrate=0.300, error=34.157
# >epoch=82, lrate=0.300, error=34.151
# >epoch=83, lrate=0.300, error=34.145
# >epoch=84, lrate=0.300, error=34.139
# >epoch=85, lrate=0.300, error=34.133
# >epoch=86, lrate=0.300, error=34.128
# >epoch=87, lrate=0.300, error=34.122
# >epoch=88, lrate=0.300, error=34.117
# >epoch=89, lrate=0.300, error=34.111
# >epoch=90, lrate=0.300, error=34.106
# >epoch=91, lrate=0.300, error=34.101
# >epoch=92, lrate=0.300, error=34.096
# >epoch=93, lrate=0.300, error=34.091
# >epoch=94, lrate=0.300, error=34.086
# >epoch=95, lrate=0.300, error=34.081
# >epoch=96, lrate=0.300, error=34.076
# >epoch=97, lrate=0.300, error=34.072
# >epoch=98, lrate=0.300, error=34.067
# >epoch=99, lrate=0.300, error=34.063
# >epoch=100, lrate=0.300, error=34.058
# >epoch=101, lrate=0.300, error=34.054
# >epoch=102, lrate=0.300, error=34.049
# >epoch=103, lrate=0.300, error=34.045
# >epoch=104, lrate=0.300, error=34.041
# >epoch=105, lrate=0.300, error=34.037
# >epoch=106, lrate=0.300, error=34.032
# >epoch=107, lrate=0.300, error=34.028
# >epoch=108, lrate=0.300, error=34.024
# >epoch=109, lrate=0.300, error=34.020
# >epoch=110, lrate=0.300, error=34.016
# >epoch=111, lrate=0.300, error=34.012
# >epoch=112, lrate=0.300, error=34.008
# >epoch=113, lrate=0.300, error=34.004
# >epoch=114, lrate=0.300, error=34.000
# >epoch=115, lrate=0.300, error=33.997
# >epoch=116, lrate=0.300, error=33.993
# >epoch=117, lrate=0.300, error=33.989
# >epoch=118, lrate=0.300, error=33.985
# >epoch=119, lrate=0.300, error=33.982
# >epoch=120, lrate=0.300, error=33.978
# >epoch=121, lrate=0.300, error=33.974
# >epoch=122, lrate=0.300, error=33.970
# >epoch=123, lrate=0.300, error=33.967
# >epoch=124, lrate=0.300, error=33.963
# >epoch=125, lrate=0.300, error=33.960
# >epoch=126, lrate=0.300, error=33.956
# >epoch=127, lrate=0.300, error=33.952
# >epoch=128, lrate=0.300, error=33.949
# >epoch=129, lrate=0.300, error=33.945
# >epoch=130, lrate=0.300, error=33.942
# >epoch=131, lrate=0.300, error=33.938
# >epoch=132, lrate=0.300, error=33.935
# >epoch=133, lrate=0.300, error=33.931
# >epoch=134, lrate=0.300, error=33.928
# >epoch=135, lrate=0.300, error=33.924
# >epoch=136, lrate=0.300, error=33.921
# >epoch=137, lrate=0.300, error=33.917
# >epoch=138, lrate=0.300, error=33.914
# >epoch=139, lrate=0.300, error=33.910
# >epoch=140, lrate=0.300, error=33.907
# >epoch=141, lrate=0.300, error=33.904
# >epoch=142, lrate=0.300, error=33.900
# >epoch=143, lrate=0.300, error=33.897
# >epoch=144, lrate=0.300, error=33.893
# >epoch=145, lrate=0.300, error=33.890
# >epoch=146, lrate=0.300, error=33.886
# >epoch=147, lrate=0.300, error=33.883
# >epoch=148, lrate=0.300, error=33.880
# >epoch=149, lrate=0.300, error=33.876
# >epoch=150, lrate=0.300, error=33.873
# >epoch=151, lrate=0.300, error=33.869
# >epoch=152, lrate=0.300, error=33.866
# >epoch=153, lrate=0.300, error=33.863
# >epoch=154, lrate=0.300, error=33.859
# >epoch=155, lrate=0.300, error=33.856
# >epoch=156, lrate=0.300, error=33.852
# >epoch=157, lrate=0.300, error=33.849
# >epoch=158, lrate=0.300, error=33.846
# >epoch=159, lrate=0.300, error=33.842
# >epoch=160, lrate=0.300, error=33.839
# >epoch=161, lrate=0.300, error=33.835
# >epoch=162, lrate=0.300, error=33.832
# >epoch=163, lrate=0.300, error=33.828
# >epoch=164, lrate=0.300, error=33.825
# >epoch=165, lrate=0.300, error=33.822
# >epoch=166, lrate=0.300, error=33.818
# >epoch=167, lrate=0.300, error=33.815
# >epoch=168, lrate=0.300, error=33.811
# >epoch=169, lrate=0.300, error=33.808
# >epoch=170, lrate=0.300, error=33.804
# >epoch=171, lrate=0.300, error=33.801
# >epoch=172, lrate=0.300, error=33.798
# >epoch=173, lrate=0.300, error=33.794
# >epoch=174, lrate=0.300, error=33.791
# >epoch=175, lrate=0.300, error=33.787
# >epoch=176, lrate=0.300, error=33.784
# >epoch=177, lrate=0.300, error=33.780
# >epoch=178, lrate=0.300, error=33.777
# >epoch=179, lrate=0.300, error=33.773
# >epoch=180, lrate=0.300, error=33.770
# >epoch=181, lrate=0.300, error=33.766
# >epoch=182, lrate=0.300, error=33.763
# >epoch=183, lrate=0.300, error=33.759
# >epoch=184, lrate=0.300, error=33.756
# >epoch=185, lrate=0.300, error=33.752
# >epoch=186, lrate=0.300, error=33.749
# >epoch=187, lrate=0.300, error=33.745
# >epoch=188, lrate=0.300, error=33.742
# >epoch=189, lrate=0.300, error=33.738
# >epoch=190, lrate=0.300, error=33.735
# >epoch=191, lrate=0.300, error=33.731
# >epoch=192, lrate=0.300, error=33.728
# >epoch=193, lrate=0.300, error=33.724
# >epoch=194, lrate=0.300, error=33.721
# >epoch=195, lrate=0.300, error=33.717
# >epoch=196, lrate=0.300, error=33.714
# >epoch=197, lrate=0.300, error=33.710
# >epoch=198, lrate=0.300, error=33.707
# >epoch=199, lrate=0.300, error=33.703
# >epoch=200, lrate=0.300, error=33.700
# >epoch=201, lrate=0.300, error=33.696
# >epoch=202, lrate=0.300, error=33.693
# >epoch=203, lrate=0.300, error=33.689
# >epoch=204, lrate=0.300, error=33.686
# >epoch=205, lrate=0.300, error=33.682
# >epoch=206, lrate=0.300, error=33.679
# >epoch=207, lrate=0.300, error=33.675
# >epoch=208, lrate=0.300, error=33.672
# >epoch=209, lrate=0.300, error=33.668
# >epoch=210, lrate=0.300, error=33.664
# >epoch=211, lrate=0.300, error=33.661
# >epoch=212, lrate=0.300, error=33.657
# >epoch=213, lrate=0.300, error=33.654
# >epoch=214, lrate=0.300, error=33.650
# >epoch=215, lrate=0.300, error=33.647
# >epoch=216, lrate=0.300, error=33.643
# >epoch=217, lrate=0.300, error=33.640
# >epoch=218, lrate=0.300, error=33.636
# >epoch=219, lrate=0.300, error=33.633
# >epoch=220, lrate=0.300, error=33.629
# >epoch=221, lrate=0.300, error=33.626
# >epoch=222, lrate=0.300, error=33.622
# >epoch=223, lrate=0.300, error=33.619
# >epoch=224, lrate=0.300, error=33.615
# >epoch=225, lrate=0.300, error=33.612
# >epoch=226, lrate=0.300, error=33.608
# >epoch=227, lrate=0.300, error=33.605
# >epoch=228, lrate=0.300, error=33.601
# >epoch=229, lrate=0.300, error=33.598
# >epoch=230, lrate=0.300, error=33.594
# >epoch=231, lrate=0.300, error=33.591
# >epoch=232, lrate=0.300, error=33.588
# >epoch=233, lrate=0.300, error=33.584
# >epoch=234, lrate=0.300, error=33.581
# >epoch=235, lrate=0.300, error=33.577
# >epoch=236, lrate=0.300, error=33.574
# >epoch=237, lrate=0.300, error=33.570
# >epoch=238, lrate=0.300, error=33.567
# >epoch=239, lrate=0.300, error=33.564
# >epoch=240, lrate=0.300, error=33.560
# >epoch=241, lrate=0.300, error=33.557
# >epoch=242, lrate=0.300, error=33.553
# >epoch=243, lrate=0.300, error=33.550
# >epoch=244, lrate=0.300, error=33.546
# >epoch=245, lrate=0.300, error=33.543
# >epoch=246, lrate=0.300, error=33.540
# >epoch=247, lrate=0.300, error=33.536
# >epoch=248, lrate=0.300, error=33.533
# >epoch=249, lrate=0.300, error=33.530
# >epoch=250, lrate=0.300, error=33.526
# >epoch=251, lrate=0.300, error=33.523
# >epoch=252, lrate=0.300, error=33.520
# >epoch=253, lrate=0.300, error=33.516
# >epoch=254, lrate=0.300, error=33.513
# >epoch=255, lrate=0.300, error=33.510
# >epoch=256, lrate=0.300, error=33.506
# >epoch=257, lrate=0.300, error=33.503
# >epoch=258, lrate=0.300, error=33.500
# >epoch=259, lrate=0.300, error=33.496
# >epoch=260, lrate=0.300, error=33.493
# >epoch=261, lrate=0.300, error=33.490
# >epoch=262, lrate=0.300, error=33.487
# >epoch=263, lrate=0.300, error=33.483
# >epoch=264, lrate=0.300, error=33.480
# >epoch=265, lrate=0.300, error=33.477
# >epoch=266, lrate=0.300, error=33.473
# >epoch=267, lrate=0.300, error=33.470
# >epoch=268, lrate=0.300, error=33.467
# >epoch=269, lrate=0.300, error=33.464
# >epoch=270, lrate=0.300, error=33.461
# >epoch=271, lrate=0.300, error=33.457
# >epoch=272, lrate=0.300, error=33.454
# >epoch=273, lrate=0.300, error=33.451
# >epoch=274, lrate=0.300, error=33.448
# >epoch=275, lrate=0.300, error=33.444
# >epoch=276, lrate=0.300, error=33.441
# >epoch=277, lrate=0.300, error=33.438
# >epoch=278, lrate=0.300, error=33.435
# >epoch=279, lrate=0.300, error=33.432
# >epoch=280, lrate=0.300, error=33.429
# >epoch=281, lrate=0.300, error=33.425
# >epoch=282, lrate=0.300, error=33.422
# >epoch=283, lrate=0.300, error=33.419
# >epoch=284, lrate=0.300, error=33.416
# >epoch=285, lrate=0.300, error=33.413
# >epoch=286, lrate=0.300, error=33.410
# >epoch=287, lrate=0.300, error=33.407
# >epoch=288, lrate=0.300, error=33.403
# >epoch=289, lrate=0.300, error=33.400
# >epoch=290, lrate=0.300, error=33.397
# >epoch=291, lrate=0.300, error=33.394
# >epoch=292, lrate=0.300, error=33.391
# >epoch=293, lrate=0.300, error=33.388
# >epoch=294, lrate=0.300, error=33.385
# >epoch=295, lrate=0.300, error=33.382
# >epoch=296, lrate=0.300, error=33.379
# >epoch=297, lrate=0.300, error=33.376
# >epoch=298, lrate=0.300, error=33.373
# >epoch=299, lrate=0.300, error=33.369
# >epoch=300, lrate=0.300, error=33.366
# >epoch=301, lrate=0.300, error=33.363
# >epoch=302, lrate=0.300, error=33.360
# >epoch=303, lrate=0.300, error=33.357
# >epoch=304, lrate=0.300, error=33.354
# >epoch=305, lrate=0.300, error=33.351
# >epoch=306, lrate=0.300, error=33.348
# >epoch=307, lrate=0.300, error=33.345
# >epoch=308, lrate=0.300, error=33.342
# >epoch=309, lrate=0.300, error=33.339
# >epoch=310, lrate=0.300, error=33.336
# >epoch=311, lrate=0.300, error=33.333
# >epoch=312, lrate=0.300, error=33.330
# >epoch=313, lrate=0.300, error=33.327
# >epoch=314, lrate=0.300, error=33.324
# >epoch=315, lrate=0.300, error=33.321
# >epoch=316, lrate=0.300, error=33.318
# >epoch=317, lrate=0.300, error=33.315
# >epoch=318, lrate=0.300, error=33.312
# >epoch=319, lrate=0.300, error=33.309
# >epoch=320, lrate=0.300, error=33.306
# >epoch=321, lrate=0.300, error=33.303
# >epoch=322, lrate=0.300, error=33.300
# >epoch=323, lrate=0.300, error=33.297
# >epoch=324, lrate=0.300, error=33.294
# >epoch=325, lrate=0.300, error=33.291
# >epoch=326, lrate=0.300, error=33.288
# >epoch=327, lrate=0.300, error=33.285
# >epoch=328, lrate=0.300, error=33.282
# >epoch=329, lrate=0.300, error=33.279
# >epoch=330, lrate=0.300, error=33.276
# >epoch=331, lrate=0.300, error=33.273
# >epoch=332, lrate=0.300, error=33.270
# >epoch=333, lrate=0.300, error=33.267
# >epoch=334, lrate=0.300, error=33.264
# >epoch=335, lrate=0.300, error=33.261
# >epoch=336, lrate=0.300, error=33.258
# >epoch=337, lrate=0.300, error=33.255
# >epoch=338, lrate=0.300, error=33.253
# >epoch=339, lrate=0.300, error=33.250
# >epoch=340, lrate=0.300, error=33.247
# >epoch=341, lrate=0.300, error=33.244
# >epoch=342, lrate=0.300, error=33.241
# >epoch=343, lrate=0.300, error=33.238
# >epoch=344, lrate=0.300, error=33.235
# >epoch=345, lrate=0.300, error=33.232
# >epoch=346, lrate=0.300, error=33.229
# >epoch=347, lrate=0.300, error=33.226
# >epoch=348, lrate=0.300, error=33.223
# >epoch=349, lrate=0.300, error=33.220
# >epoch=350, lrate=0.300, error=33.217
# >epoch=351, lrate=0.300, error=33.214
# >epoch=352, lrate=0.300, error=33.211
# >epoch=353, lrate=0.300, error=33.208
# >epoch=354, lrate=0.300, error=33.205
# >epoch=355, lrate=0.300, error=33.203
# >epoch=356, lrate=0.300, error=33.200
# >epoch=357, lrate=0.300, error=33.197
# >epoch=358, lrate=0.300, error=33.194
# >epoch=359, lrate=0.300, error=33.191
# >epoch=360, lrate=0.300, error=33.188
# >epoch=361, lrate=0.300, error=33.185
# >epoch=362, lrate=0.300, error=33.182
# >epoch=363, lrate=0.300, error=33.179
# >epoch=364, lrate=0.300, error=33.176
# >epoch=365, lrate=0.300, error=33.173
# >epoch=366, lrate=0.300, error=33.170
# >epoch=367, lrate=0.300, error=33.167
# >epoch=368, lrate=0.300, error=33.164
# >epoch=369, lrate=0.300, error=33.162
# >epoch=370, lrate=0.300, error=33.159
# >epoch=371, lrate=0.300, error=33.156
# >epoch=372, lrate=0.300, error=33.153
# >epoch=373, lrate=0.300, error=33.150
# >epoch=374, lrate=0.300, error=33.147
# >epoch=375, lrate=0.300, error=33.144
# >epoch=376, lrate=0.300, error=33.141
# >epoch=377, lrate=0.300, error=33.138
# >epoch=378, lrate=0.300, error=33.135
# >epoch=379, lrate=0.300, error=33.132
# >epoch=380, lrate=0.300, error=33.129
# >epoch=381, lrate=0.300, error=33.126
# >epoch=382, lrate=0.300, error=33.124
# >epoch=383, lrate=0.300, error=33.121
# >epoch=384, lrate=0.300, error=33.118
# >epoch=385, lrate=0.300, error=33.115
# >epoch=386, lrate=0.300, error=33.112
# >epoch=387, lrate=0.300, error=33.109
# >epoch=388, lrate=0.300, error=33.106
# >epoch=389, lrate=0.300, error=33.103
# >epoch=390, lrate=0.300, error=33.100
# >epoch=391, lrate=0.300, error=33.097
# >epoch=392, lrate=0.300, error=33.094
# >epoch=393, lrate=0.300, error=33.091
# >epoch=394, lrate=0.300, error=33.088
# >epoch=395, lrate=0.300, error=33.085
# >epoch=396, lrate=0.300, error=33.083
# >epoch=397, lrate=0.300, error=33.080
# >epoch=398, lrate=0.300, error=33.077
# >epoch=399, lrate=0.300, error=33.074
# >epoch=400, lrate=0.300, error=33.071
# >epoch=401, lrate=0.300, error=33.068
# >epoch=402, lrate=0.300, error=33.065
# >epoch=403, lrate=0.300, error=33.062
# >epoch=404, lrate=0.300, error=33.059
# >epoch=405, lrate=0.300, error=33.056
# >epoch=406, lrate=0.300, error=33.053
# >epoch=407, lrate=0.300, error=33.050
# >epoch=408, lrate=0.300, error=33.047
# >epoch=409, lrate=0.300, error=33.044
# >epoch=410, lrate=0.300, error=33.041
# >epoch=411, lrate=0.300, error=33.038
# >epoch=412, lrate=0.300, error=33.036
# >epoch=413, lrate=0.300, error=33.033
# >epoch=414, lrate=0.300, error=33.030
# >epoch=415, lrate=0.300, error=33.027
# >epoch=416, lrate=0.300, error=33.024
# >epoch=417, lrate=0.300, error=33.021
# >epoch=418, lrate=0.300, error=33.018
# >epoch=419, lrate=0.300, error=33.015
# >epoch=420, lrate=0.300, error=33.012
# >epoch=421, lrate=0.300, error=33.009
# >epoch=422, lrate=0.300, error=33.006
# >epoch=423, lrate=0.300, error=33.003
# >epoch=424, lrate=0.300, error=33.000
# >epoch=425, lrate=0.300, error=32.997
# >epoch=426, lrate=0.300, error=32.995
# >epoch=427, lrate=0.300, error=32.992
# >epoch=428, lrate=0.300, error=32.989
# >epoch=429, lrate=0.300, error=32.986
# >epoch=430, lrate=0.300, error=32.983
# >epoch=431, lrate=0.300, error=32.980
# >epoch=432, lrate=0.300, error=32.977
# >epoch=433, lrate=0.300, error=32.974
# >epoch=434, lrate=0.300, error=32.971
# >epoch=435, lrate=0.300, error=32.968
# >epoch=436, lrate=0.300, error=32.965
# >epoch=437, lrate=0.300, error=32.962
# >epoch=438, lrate=0.300, error=32.959
# >epoch=439, lrate=0.300, error=32.957
# >epoch=440, lrate=0.300, error=32.954
# >epoch=441, lrate=0.300, error=32.951
# >epoch=442, lrate=0.300, error=32.948
# >epoch=443, lrate=0.300, error=32.945
# >epoch=444, lrate=0.300, error=32.942
# >epoch=445, lrate=0.300, error=32.939
# >epoch=446, lrate=0.300, error=32.936
# >epoch=447, lrate=0.300, error=32.933
# >epoch=448, lrate=0.300, error=32.930
# >epoch=449, lrate=0.300, error=32.928
# >epoch=450, lrate=0.300, error=32.925
# >epoch=451, lrate=0.300, error=32.922
# >epoch=452, lrate=0.300, error=32.919
# >epoch=453, lrate=0.300, error=32.916
# >epoch=454, lrate=0.300, error=32.913
# >epoch=455, lrate=0.300, error=32.910
# >epoch=456, lrate=0.300, error=32.907
# >epoch=457, lrate=0.300, error=32.904
# >epoch=458, lrate=0.300, error=32.902
# >epoch=459, lrate=0.300, error=32.899
# >epoch=460, lrate=0.300, error=32.896
# >epoch=461, lrate=0.300, error=32.893
# >epoch=462, lrate=0.300, error=32.890
# >epoch=463, lrate=0.300, error=32.887
# >epoch=464, lrate=0.300, error=32.884
# >epoch=465, lrate=0.300, error=32.882
# >epoch=466, lrate=0.300, error=32.879
# >epoch=467, lrate=0.300, error=32.876
# >epoch=468, lrate=0.300, error=32.873
# >epoch=469, lrate=0.300, error=32.870
# >epoch=470, lrate=0.300, error=32.868
# >epoch=471, lrate=0.300, error=32.865
# >epoch=472, lrate=0.300, error=32.862
# >epoch=473, lrate=0.300, error=32.859
# >epoch=474, lrate=0.300, error=32.856
# >epoch=475, lrate=0.300, error=32.853
# >epoch=476, lrate=0.300, error=32.851
# >epoch=477, lrate=0.300, error=32.848
# >epoch=478, lrate=0.300, error=32.845
# >epoch=479, lrate=0.300, error=32.842
# >epoch=480, lrate=0.300, error=32.840
# >epoch=481, lrate=0.300, error=32.837
# >epoch=482, lrate=0.300, error=32.834
# >epoch=483, lrate=0.300, error=32.831
# >epoch=484, lrate=0.300, error=32.829
# >epoch=485, lrate=0.300, error=32.826
# >epoch=486, lrate=0.300, error=32.823
# >epoch=487, lrate=0.300, error=32.820
# >epoch=488, lrate=0.300, error=32.818
# >epoch=489, lrate=0.300, error=32.815
# >epoch=490, lrate=0.300, error=32.812
# >epoch=491, lrate=0.300, error=32.809
# >epoch=492, lrate=0.300, error=32.807
# >epoch=493, lrate=0.300, error=32.804
# >epoch=494, lrate=0.300, error=32.801
# >epoch=495, lrate=0.300, error=32.799
# >epoch=496, lrate=0.300, error=32.796
# >epoch=497, lrate=0.300, error=32.793
# >epoch=498, lrate=0.300, error=32.790
# >epoch=499, lrate=0.300, error=32.788
# >epoch=0, lrate=0.300, error=87.026
# >epoch=1, lrate=0.300, error=80.456
# >epoch=2, lrate=0.300, error=78.955
# >epoch=3, lrate=0.300, error=76.905
# >epoch=4, lrate=0.300, error=73.976
# >epoch=5, lrate=0.300, error=69.825
# >epoch=6, lrate=0.300, error=64.332
# >epoch=7, lrate=0.300, error=57.976
# >epoch=8, lrate=0.300, error=51.797
# >epoch=9, lrate=0.300, error=46.685
# >epoch=10, lrate=0.300, error=42.881
# >epoch=11, lrate=0.300, error=40.188
# >epoch=12, lrate=0.300, error=38.299
# >epoch=13, lrate=0.300, error=36.964
# >epoch=14, lrate=0.300, error=36.005
# >epoch=15, lrate=0.300, error=35.303
# >epoch=16, lrate=0.300, error=34.782
# >epoch=17, lrate=0.300, error=34.388
# >epoch=18, lrate=0.300, error=34.087
# >epoch=19, lrate=0.300, error=33.853
# >epoch=20, lrate=0.300, error=33.671
# >epoch=21, lrate=0.300, error=33.527
# >epoch=22, lrate=0.300, error=33.412
# >epoch=23, lrate=0.300, error=33.320
# >epoch=24, lrate=0.300, error=33.245
# >epoch=25, lrate=0.300, error=33.185
# >epoch=26, lrate=0.300, error=33.135
# >epoch=27, lrate=0.300, error=33.095
# >epoch=28, lrate=0.300, error=33.061
# >epoch=29, lrate=0.300, error=33.033
# >epoch=30, lrate=0.300, error=33.010
# >epoch=31, lrate=0.300, error=32.990
# >epoch=32, lrate=0.300, error=32.973
# >epoch=33, lrate=0.300, error=32.959
# >epoch=34, lrate=0.300, error=32.947
# >epoch=35, lrate=0.300, error=32.936
# >epoch=36, lrate=0.300, error=32.926
# >epoch=37, lrate=0.300, error=32.918
# >epoch=38, lrate=0.300, error=32.911
# >epoch=39, lrate=0.300, error=32.904
# >epoch=40, lrate=0.300, error=32.898
# >epoch=41, lrate=0.300, error=32.892
# >epoch=42, lrate=0.300, error=32.887
# >epoch=43, lrate=0.300, error=32.882
# >epoch=44, lrate=0.300, error=32.877
# >epoch=45, lrate=0.300, error=32.872
# >epoch=46, lrate=0.300, error=32.867
# >epoch=47, lrate=0.300, error=32.863
# >epoch=48, lrate=0.300, error=32.858
# >epoch=49, lrate=0.300, error=32.854
# >epoch=50, lrate=0.300, error=32.849
# >epoch=51, lrate=0.300, error=32.845
# >epoch=52, lrate=0.300, error=32.840
# >epoch=53, lrate=0.300, error=32.836
# >epoch=54, lrate=0.300, error=32.831
# >epoch=55, lrate=0.300, error=32.826
# >epoch=56, lrate=0.300, error=32.822
# >epoch=57, lrate=0.300, error=32.817
# >epoch=58, lrate=0.300, error=32.812
# >epoch=59, lrate=0.300, error=32.807
# >epoch=60, lrate=0.300, error=32.802
# >epoch=61, lrate=0.300, error=32.797
# >epoch=62, lrate=0.300, error=32.791
# >epoch=63, lrate=0.300, error=32.786
# >epoch=64, lrate=0.300, error=32.780
# >epoch=65, lrate=0.300, error=32.775
# >epoch=66, lrate=0.300, error=32.769
# >epoch=67, lrate=0.300, error=32.763
# >epoch=68, lrate=0.300, error=32.758
# >epoch=69, lrate=0.300, error=32.752
# >epoch=70, lrate=0.300, error=32.746
# >epoch=71, lrate=0.300, error=32.740
# >epoch=72, lrate=0.300, error=32.733
# >epoch=73, lrate=0.300, error=32.727
# >epoch=74, lrate=0.300, error=32.721
# >epoch=75, lrate=0.300, error=32.714
# >epoch=76, lrate=0.300, error=32.708
# >epoch=77, lrate=0.300, error=32.701
# >epoch=78, lrate=0.300, error=32.694
# >epoch=79, lrate=0.300, error=32.688
# >epoch=80, lrate=0.300, error=32.681
# >epoch=81, lrate=0.300, error=32.674
# >epoch=82, lrate=0.300, error=32.667
# >epoch=83, lrate=0.300, error=32.660
# >epoch=84, lrate=0.300, error=32.653
# >epoch=85, lrate=0.300, error=32.645
# >epoch=86, lrate=0.300, error=32.638
# >epoch=87, lrate=0.300, error=32.631
# >epoch=88, lrate=0.300, error=32.624
# >epoch=89, lrate=0.300, error=32.617
# >epoch=90, lrate=0.300, error=32.609
# >epoch=91, lrate=0.300, error=32.602
# >epoch=92, lrate=0.300, error=32.595
# >epoch=93, lrate=0.300, error=32.587
# >epoch=94, lrate=0.300, error=32.580
# >epoch=95, lrate=0.300, error=32.573
# >epoch=96, lrate=0.300, error=32.566
# >epoch=97, lrate=0.300, error=32.558
# >epoch=98, lrate=0.300, error=32.551
# >epoch=99, lrate=0.300, error=32.544
# >epoch=100, lrate=0.300, error=32.537
# >epoch=101, lrate=0.300, error=32.530
# >epoch=102, lrate=0.300, error=32.522
# >epoch=103, lrate=0.300, error=32.515
# >epoch=104, lrate=0.300, error=32.508
# >epoch=105, lrate=0.300, error=32.501
# >epoch=106, lrate=0.300, error=32.494
# >epoch=107, lrate=0.300, error=32.487
# >epoch=108, lrate=0.300, error=32.481
# >epoch=109, lrate=0.300, error=32.474
# >epoch=110, lrate=0.300, error=32.467
# >epoch=111, lrate=0.300, error=32.460
# >epoch=112, lrate=0.300, error=32.454
# >epoch=113, lrate=0.300, error=32.447
# >epoch=114, lrate=0.300, error=32.440
# >epoch=115, lrate=0.300, error=32.434
# >epoch=116, lrate=0.300, error=32.427
# >epoch=117, lrate=0.300, error=32.421
# >epoch=118, lrate=0.300, error=32.414
# >epoch=119, lrate=0.300, error=32.408
# >epoch=120, lrate=0.300, error=32.402
# >epoch=121, lrate=0.300, error=32.395
# >epoch=122, lrate=0.300, error=32.389
# >epoch=123, lrate=0.300, error=32.383
# >epoch=124, lrate=0.300, error=32.377
# >epoch=125, lrate=0.300, error=32.371
# >epoch=126, lrate=0.300, error=32.364
# >epoch=127, lrate=0.300, error=32.358
# >epoch=128, lrate=0.300, error=32.352
# >epoch=129, lrate=0.300, error=32.346
# >epoch=130, lrate=0.300, error=32.341
# >epoch=131, lrate=0.300, error=32.335
# >epoch=132, lrate=0.300, error=32.329
# >epoch=133, lrate=0.300, error=32.323
# >epoch=134, lrate=0.300, error=32.317
# >epoch=135, lrate=0.300, error=32.311
# >epoch=136, lrate=0.300, error=32.306
# >epoch=137, lrate=0.300, error=32.300
# >epoch=138, lrate=0.300, error=32.294
# >epoch=139, lrate=0.300, error=32.289
# >epoch=140, lrate=0.300, error=32.283
# >epoch=141, lrate=0.300, error=32.278
# >epoch=142, lrate=0.300, error=32.272
# >epoch=143, lrate=0.300, error=32.267
# >epoch=144, lrate=0.300, error=32.261
# >epoch=145, lrate=0.300, error=32.256
# >epoch=146, lrate=0.300, error=32.251
# >epoch=147, lrate=0.300, error=32.245
# >epoch=148, lrate=0.300, error=32.240
# >epoch=149, lrate=0.300, error=32.235
# >epoch=150, lrate=0.300, error=32.229
# >epoch=151, lrate=0.300, error=32.224
# >epoch=152, lrate=0.300, error=32.219
# >epoch=153, lrate=0.300, error=32.214
# >epoch=154, lrate=0.300, error=32.209
# >epoch=155, lrate=0.300, error=32.204
# >epoch=156, lrate=0.300, error=32.198
# >epoch=157, lrate=0.300, error=32.193
# >epoch=158, lrate=0.300, error=32.188
# >epoch=159, lrate=0.300, error=32.183
# >epoch=160, lrate=0.300, error=32.178
# >epoch=161, lrate=0.300, error=32.173
# >epoch=162, lrate=0.300, error=32.169
# >epoch=163, lrate=0.300, error=32.164
# >epoch=164, lrate=0.300, error=32.159
# >epoch=165, lrate=0.300, error=32.154
# >epoch=166, lrate=0.300, error=32.149
# >epoch=167, lrate=0.300, error=32.144
# >epoch=168, lrate=0.300, error=32.140
# >epoch=169, lrate=0.300, error=32.135
# >epoch=170, lrate=0.300, error=32.130
# >epoch=171, lrate=0.300, error=32.126
# >epoch=172, lrate=0.300, error=32.121
# >epoch=173, lrate=0.300, error=32.116
# >epoch=174, lrate=0.300, error=32.112
# >epoch=175, lrate=0.300, error=32.107
# >epoch=176, lrate=0.300, error=32.103
# >epoch=177, lrate=0.300, error=32.098
# >epoch=178, lrate=0.300, error=32.093
# >epoch=179, lrate=0.300, error=32.089
# >epoch=180, lrate=0.300, error=32.085
# >epoch=181, lrate=0.300, error=32.080
# >epoch=182, lrate=0.300, error=32.076
# >epoch=183, lrate=0.300, error=32.071
# >epoch=184, lrate=0.300, error=32.067
# >epoch=185, lrate=0.300, error=32.063
# >epoch=186, lrate=0.300, error=32.058
# >epoch=187, lrate=0.300, error=32.054
# >epoch=188, lrate=0.300, error=32.050
# >epoch=189, lrate=0.300, error=32.045
# >epoch=190, lrate=0.300, error=32.041
# >epoch=191, lrate=0.300, error=32.037
# >epoch=192, lrate=0.300, error=32.033
# >epoch=193, lrate=0.300, error=32.029
# >epoch=194, lrate=0.300, error=32.024
# >epoch=195, lrate=0.300, error=32.020
# >epoch=196, lrate=0.300, error=32.016
# >epoch=197, lrate=0.300, error=32.012
# >epoch=198, lrate=0.300, error=32.008
# >epoch=199, lrate=0.300, error=32.004
# >epoch=200, lrate=0.300, error=32.000
# >epoch=201, lrate=0.300, error=31.996
# >epoch=202, lrate=0.300, error=31.992
# >epoch=203, lrate=0.300, error=31.988
# >epoch=204, lrate=0.300, error=31.984
# >epoch=205, lrate=0.300, error=31.980
# >epoch=206, lrate=0.300, error=31.976
# >epoch=207, lrate=0.300, error=31.972
# >epoch=208, lrate=0.300, error=31.968
# >epoch=209, lrate=0.300, error=31.965
# >epoch=210, lrate=0.300, error=31.961
# >epoch=211, lrate=0.300, error=31.957
# >epoch=212, lrate=0.300, error=31.953
# >epoch=213, lrate=0.300, error=31.949
# >epoch=214, lrate=0.300, error=31.946
# >epoch=215, lrate=0.300, error=31.942
# >epoch=216, lrate=0.300, error=31.938
# >epoch=217, lrate=0.300, error=31.934
# >epoch=218, lrate=0.300, error=31.931
# >epoch=219, lrate=0.300, error=31.927
# >epoch=220, lrate=0.300, error=31.923
# >epoch=221, lrate=0.300, error=31.920
# >epoch=222, lrate=0.300, error=31.916
# >epoch=223, lrate=0.300, error=31.913
# >epoch=224, lrate=0.300, error=31.909
# >epoch=225, lrate=0.300, error=31.905
# >epoch=226, lrate=0.300, error=31.902
# >epoch=227, lrate=0.300, error=31.898
# >epoch=228, lrate=0.300, error=31.895
# >epoch=229, lrate=0.300, error=31.891
# >epoch=230, lrate=0.300, error=31.888
# >epoch=231, lrate=0.300, error=31.884
# >epoch=232, lrate=0.300, error=31.881
# >epoch=233, lrate=0.300, error=31.877
# >epoch=234, lrate=0.300, error=31.874
# >epoch=235, lrate=0.300, error=31.871
# >epoch=236, lrate=0.300, error=31.867
# >epoch=237, lrate=0.300, error=31.864
# >epoch=238, lrate=0.300, error=31.861
# >epoch=239, lrate=0.300, error=31.857
# >epoch=240, lrate=0.300, error=31.854
# >epoch=241, lrate=0.300, error=31.851
# >epoch=242, lrate=0.300, error=31.847
# >epoch=243, lrate=0.300, error=31.844
# >epoch=244, lrate=0.300, error=31.841
# >epoch=245, lrate=0.300, error=31.837
# >epoch=246, lrate=0.300, error=31.834
# >epoch=247, lrate=0.300, error=31.831
# >epoch=248, lrate=0.300, error=31.828
# >epoch=249, lrate=0.300, error=31.825
# >epoch=250, lrate=0.300, error=31.821
# >epoch=251, lrate=0.300, error=31.818
# >epoch=252, lrate=0.300, error=31.815
# >epoch=253, lrate=0.300, error=31.812
# >epoch=254, lrate=0.300, error=31.809
# >epoch=255, lrate=0.300, error=31.806
# >epoch=256, lrate=0.300, error=31.803
# >epoch=257, lrate=0.300, error=31.800
# >epoch=258, lrate=0.300, error=31.796
# >epoch=259, lrate=0.300, error=31.793
# >epoch=260, lrate=0.300, error=31.790
# >epoch=261, lrate=0.300, error=31.787
# >epoch=262, lrate=0.300, error=31.784
# >epoch=263, lrate=0.300, error=31.781
# >epoch=264, lrate=0.300, error=31.778
# >epoch=265, lrate=0.300, error=31.775
# >epoch=266, lrate=0.300, error=31.772
# >epoch=267, lrate=0.300, error=31.769
# >epoch=268, lrate=0.300, error=31.766
# >epoch=269, lrate=0.300, error=31.763
# >epoch=270, lrate=0.300, error=31.761
# >epoch=271, lrate=0.300, error=31.758
# >epoch=272, lrate=0.300, error=31.755
# >epoch=273, lrate=0.300, error=31.752
# >epoch=274, lrate=0.300, error=31.749
# >epoch=275, lrate=0.300, error=31.746
# >epoch=276, lrate=0.300, error=31.743
# >epoch=277, lrate=0.300, error=31.740
# >epoch=278, lrate=0.300, error=31.738
# >epoch=279, lrate=0.300, error=31.735
# >epoch=280, lrate=0.300, error=31.732
# >epoch=281, lrate=0.300, error=31.729
# >epoch=282, lrate=0.300, error=31.726
# >epoch=283, lrate=0.300, error=31.724
# >epoch=284, lrate=0.300, error=31.721
# >epoch=285, lrate=0.300, error=31.718
# >epoch=286, lrate=0.300, error=31.715
# >epoch=287, lrate=0.300, error=31.713
# >epoch=288, lrate=0.300, error=31.710
# >epoch=289, lrate=0.300, error=31.707
# >epoch=290, lrate=0.300, error=31.705
# >epoch=291, lrate=0.300, error=31.702
# >epoch=292, lrate=0.300, error=31.699
# >epoch=293, lrate=0.300, error=31.697
# >epoch=294, lrate=0.300, error=31.694
# >epoch=295, lrate=0.300, error=31.691
# >epoch=296, lrate=0.300, error=31.689
# >epoch=297, lrate=0.300, error=31.686
# >epoch=298, lrate=0.300, error=31.683
# >epoch=299, lrate=0.300, error=31.681
# >epoch=300, lrate=0.300, error=31.678
# >epoch=301, lrate=0.300, error=31.676
# >epoch=302, lrate=0.300, error=31.673
# >epoch=303, lrate=0.300, error=31.671
# >epoch=304, lrate=0.300, error=31.668
# >epoch=305, lrate=0.300, error=31.665
# >epoch=306, lrate=0.300, error=31.663
# >epoch=307, lrate=0.300, error=31.660
# >epoch=308, lrate=0.300, error=31.658
# >epoch=309, lrate=0.300, error=31.655
# >epoch=310, lrate=0.300, error=31.653
# >epoch=311, lrate=0.300, error=31.650
# >epoch=312, lrate=0.300, error=31.648
# >epoch=313, lrate=0.300, error=31.645
# >epoch=314, lrate=0.300, error=31.643
# >epoch=315, lrate=0.300, error=31.641
# >epoch=316, lrate=0.300, error=31.638
# >epoch=317, lrate=0.300, error=31.636
# >epoch=318, lrate=0.300, error=31.633
# >epoch=319, lrate=0.300, error=31.631
# >epoch=320, lrate=0.300, error=31.628
# >epoch=321, lrate=0.300, error=31.626
# >epoch=322, lrate=0.300, error=31.624
# >epoch=323, lrate=0.300, error=31.621
# >epoch=324, lrate=0.300, error=31.619
# >epoch=325, lrate=0.300, error=31.617
# >epoch=326, lrate=0.300, error=31.614
# >epoch=327, lrate=0.300, error=31.612
# >epoch=328, lrate=0.300, error=31.610
# >epoch=329, lrate=0.300, error=31.607
# >epoch=330, lrate=0.300, error=31.605
# >epoch=331, lrate=0.300, error=31.603
# >epoch=332, lrate=0.300, error=31.600
# >epoch=333, lrate=0.300, error=31.598
# >epoch=334, lrate=0.300, error=31.596
# >epoch=335, lrate=0.300, error=31.594
# >epoch=336, lrate=0.300, error=31.591
# >epoch=337, lrate=0.300, error=31.589
# >epoch=338, lrate=0.300, error=31.587
# >epoch=339, lrate=0.300, error=31.585
# >epoch=340, lrate=0.300, error=31.582
# >epoch=341, lrate=0.300, error=31.580
# >epoch=342, lrate=0.300, error=31.578
# >epoch=343, lrate=0.300, error=31.576
# >epoch=344, lrate=0.300, error=31.573
# >epoch=345, lrate=0.300, error=31.571
# >epoch=346, lrate=0.300, error=31.569
# >epoch=347, lrate=0.300, error=31.567
# >epoch=348, lrate=0.300, error=31.565
# >epoch=349, lrate=0.300, error=31.563
# >epoch=350, lrate=0.300, error=31.560
# >epoch=351, lrate=0.300, error=31.558
# >epoch=352, lrate=0.300, error=31.556
# >epoch=353, lrate=0.300, error=31.554
# >epoch=354, lrate=0.300, error=31.552
# >epoch=355, lrate=0.300, error=31.550
# >epoch=356, lrate=0.300, error=31.548
# >epoch=357, lrate=0.300, error=31.546
# >epoch=358, lrate=0.300, error=31.543
# >epoch=359, lrate=0.300, error=31.541
# >epoch=360, lrate=0.300, error=31.539
# >epoch=361, lrate=0.300, error=31.537
# >epoch=362, lrate=0.300, error=31.535
# >epoch=363, lrate=0.300, error=31.533
# >epoch=364, lrate=0.300, error=31.531
# >epoch=365, lrate=0.300, error=31.529
# >epoch=366, lrate=0.300, error=31.527
# >epoch=367, lrate=0.300, error=31.525
# >epoch=368, lrate=0.300, error=31.523
# >epoch=369, lrate=0.300, error=31.521
# >epoch=370, lrate=0.300, error=31.519
# >epoch=371, lrate=0.300, error=31.517
# >epoch=372, lrate=0.300, error=31.515
# >epoch=373, lrate=0.300, error=31.513
# >epoch=374, lrate=0.300, error=31.511
# >epoch=375, lrate=0.300, error=31.509
# >epoch=376, lrate=0.300, error=31.507
# >epoch=377, lrate=0.300, error=31.505
# >epoch=378, lrate=0.300, error=31.503
# >epoch=379, lrate=0.300, error=31.501
# >epoch=380, lrate=0.300, error=31.499
# >epoch=381, lrate=0.300, error=31.497
# >epoch=382, lrate=0.300, error=31.495
# >epoch=383, lrate=0.300, error=31.493
# >epoch=384, lrate=0.300, error=31.491
# >epoch=385, lrate=0.300, error=31.489
# >epoch=386, lrate=0.300, error=31.487
# >epoch=387, lrate=0.300, error=31.486
# >epoch=388, lrate=0.300, error=31.484
# >epoch=389, lrate=0.300, error=31.482
# >epoch=390, lrate=0.300, error=31.480
# >epoch=391, lrate=0.300, error=31.478
# >epoch=392, lrate=0.300, error=31.476
# >epoch=393, lrate=0.300, error=31.474
# >epoch=394, lrate=0.300, error=31.472
# >epoch=395, lrate=0.300, error=31.471
# >epoch=396, lrate=0.300, error=31.469
# >epoch=397, lrate=0.300, error=31.467
# >epoch=398, lrate=0.300, error=31.465
# >epoch=399, lrate=0.300, error=31.463
# >epoch=400, lrate=0.300, error=31.461
# >epoch=401, lrate=0.300, error=31.460
# >epoch=402, lrate=0.300, error=31.458
# >epoch=403, lrate=0.300, error=31.456
# >epoch=404, lrate=0.300, error=31.454
# >epoch=405, lrate=0.300, error=31.452
# >epoch=406, lrate=0.300, error=31.450
# >epoch=407, lrate=0.300, error=31.449
# >epoch=408, lrate=0.300, error=31.447
# >epoch=409, lrate=0.300, error=31.445
# >epoch=410, lrate=0.300, error=31.443
# >epoch=411, lrate=0.300, error=31.442
# >epoch=412, lrate=0.300, error=31.440
# >epoch=413, lrate=0.300, error=31.438
# >epoch=414, lrate=0.300, error=31.436
# >epoch=415, lrate=0.300, error=31.435
# >epoch=416, lrate=0.300, error=31.433
# >epoch=417, lrate=0.300, error=31.431
# >epoch=418, lrate=0.300, error=31.429
# >epoch=419, lrate=0.300, error=31.428
# >epoch=420, lrate=0.300, error=31.426
# >epoch=421, lrate=0.300, error=31.424
# >epoch=422, lrate=0.300, error=31.423
# >epoch=423, lrate=0.300, error=31.421
# >epoch=424, lrate=0.300, error=31.419
# >epoch=425, lrate=0.300, error=31.417
# >epoch=426, lrate=0.300, error=31.416
# >epoch=427, lrate=0.300, error=31.414
# >epoch=428, lrate=0.300, error=31.412
# >epoch=429, lrate=0.300, error=31.411
# >epoch=430, lrate=0.300, error=31.409
# >epoch=431, lrate=0.300, error=31.407
# >epoch=432, lrate=0.300, error=31.406
# >epoch=433, lrate=0.300, error=31.404
# >epoch=434, lrate=0.300, error=31.402
# >epoch=435, lrate=0.300, error=31.401
# >epoch=436, lrate=0.300, error=31.399
# >epoch=437, lrate=0.300, error=31.398
# >epoch=438, lrate=0.300, error=31.396
# >epoch=439, lrate=0.300, error=31.394
# >epoch=440, lrate=0.300, error=31.393
# >epoch=441, lrate=0.300, error=31.391
# >epoch=442, lrate=0.300, error=31.389
# >epoch=443, lrate=0.300, error=31.388
# >epoch=444, lrate=0.300, error=31.386
# >epoch=445, lrate=0.300, error=31.385
# >epoch=446, lrate=0.300, error=31.383
# >epoch=447, lrate=0.300, error=31.381
# >epoch=448, lrate=0.300, error=31.380
# >epoch=449, lrate=0.300, error=31.378
# >epoch=450, lrate=0.300, error=31.377
# >epoch=451, lrate=0.300, error=31.375
# >epoch=452, lrate=0.300, error=31.374
# >epoch=453, lrate=0.300, error=31.372
# >epoch=454, lrate=0.300, error=31.370
# >epoch=455, lrate=0.300, error=31.369
# >epoch=456, lrate=0.300, error=31.367
# >epoch=457, lrate=0.300, error=31.366
# >epoch=458, lrate=0.300, error=31.364
# >epoch=459, lrate=0.300, error=31.363
# >epoch=460, lrate=0.300, error=31.361
# >epoch=461, lrate=0.300, error=31.360
# >epoch=462, lrate=0.300, error=31.358
# >epoch=463, lrate=0.300, error=31.357
# >epoch=464, lrate=0.300, error=31.355
# >epoch=465, lrate=0.300, error=31.354
# >epoch=466, lrate=0.300, error=31.352
# >epoch=467, lrate=0.300, error=31.351
# >epoch=468, lrate=0.300, error=31.349
# >epoch=469, lrate=0.300, error=31.348
# >epoch=470, lrate=0.300, error=31.346
# >epoch=471, lrate=0.300, error=31.345
# >epoch=472, lrate=0.300, error=31.343
# >epoch=473, lrate=0.300, error=31.342
# >epoch=474, lrate=0.300, error=31.340
# >epoch=475, lrate=0.300, error=31.339
# >epoch=476, lrate=0.300, error=31.337
# >epoch=477, lrate=0.300, error=31.336
# >epoch=478, lrate=0.300, error=31.334
# >epoch=479, lrate=0.300, error=31.333
# >epoch=480, lrate=0.300, error=31.332
# >epoch=481, lrate=0.300, error=31.330
# >epoch=482, lrate=0.300, error=31.329
# >epoch=483, lrate=0.300, error=31.327
# >epoch=484, lrate=0.300, error=31.326
# >epoch=485, lrate=0.300, error=31.324
# >epoch=486, lrate=0.300, error=31.323
# >epoch=487, lrate=0.300, error=31.322
# >epoch=488, lrate=0.300, error=31.320
# >epoch=489, lrate=0.300, error=31.319
# >epoch=490, lrate=0.300, error=31.317
# >epoch=491, lrate=0.300, error=31.316
# >epoch=492, lrate=0.300, error=31.315
# >epoch=493, lrate=0.300, error=31.313
# >epoch=494, lrate=0.300, error=31.312
# >epoch=495, lrate=0.300, error=31.310
# >epoch=496, lrate=0.300, error=31.309
# >epoch=497, lrate=0.300, error=31.308
# >epoch=498, lrate=0.300, error=31.306
# >epoch=499, lrate=0.300, error=31.305
# >epoch=0, lrate=0.300, error=87.941
# >epoch=1, lrate=0.300, error=81.482
# >epoch=2, lrate=0.300, error=79.640
# >epoch=3, lrate=0.300, error=76.597
# >epoch=4, lrate=0.300, error=71.581
# >epoch=5, lrate=0.300, error=64.256
# >epoch=6, lrate=0.300, error=55.745
# >epoch=7, lrate=0.300, error=48.041
# >epoch=8, lrate=0.300, error=42.237
# >epoch=9, lrate=0.300, error=38.254
# >epoch=10, lrate=0.300, error=35.589
# >epoch=11, lrate=0.300, error=33.789
# >epoch=12, lrate=0.300, error=32.542
# >epoch=13, lrate=0.300, error=31.656
# >epoch=14, lrate=0.300, error=31.010
# >epoch=15, lrate=0.300, error=30.529
# >epoch=16, lrate=0.300, error=30.163
# >epoch=17, lrate=0.300, error=29.881
# >epoch=18, lrate=0.300, error=29.659
# >epoch=19, lrate=0.300, error=29.484
# >epoch=20, lrate=0.300, error=29.343
# >epoch=21, lrate=0.300, error=29.229
# >epoch=22, lrate=0.300, error=29.137
# >epoch=23, lrate=0.300, error=29.060
# >epoch=24, lrate=0.300, error=28.997
# >epoch=25, lrate=0.300, error=28.944
# >epoch=26, lrate=0.300, error=28.900
# >epoch=27, lrate=0.300, error=28.863
# >epoch=28, lrate=0.300, error=28.832
# >epoch=29, lrate=0.300, error=28.805
# >epoch=30, lrate=0.300, error=28.782
# >epoch=31, lrate=0.300, error=28.762
# >epoch=32, lrate=0.300, error=28.745
# >epoch=33, lrate=0.300, error=28.730
# >epoch=34, lrate=0.300, error=28.716
# >epoch=35, lrate=0.300, error=28.704
# >epoch=36, lrate=0.300, error=28.693
# >epoch=37, lrate=0.300, error=28.684
# >epoch=38, lrate=0.300, error=28.675
# >epoch=39, lrate=0.300, error=28.666
# >epoch=40, lrate=0.300, error=28.659
# >epoch=41, lrate=0.300, error=28.651
# >epoch=42, lrate=0.300, error=28.644
# >epoch=43, lrate=0.300, error=28.637
# >epoch=44, lrate=0.300, error=28.631
# >epoch=45, lrate=0.300, error=28.624
# >epoch=46, lrate=0.300, error=28.618
# >epoch=47, lrate=0.300, error=28.611
# >epoch=48, lrate=0.300, error=28.605
# >epoch=49, lrate=0.300, error=28.598
# >epoch=50, lrate=0.300, error=28.591
# >epoch=51, lrate=0.300, error=28.585
# >epoch=52, lrate=0.300, error=28.578
# >epoch=53, lrate=0.300, error=28.571
# >epoch=54, lrate=0.300, error=28.563
# >epoch=55, lrate=0.300, error=28.556
# >epoch=56, lrate=0.300, error=28.548
# >epoch=57, lrate=0.300, error=28.541
# >epoch=58, lrate=0.300, error=28.533
# >epoch=59, lrate=0.300, error=28.525
# >epoch=60, lrate=0.300, error=28.516
# >epoch=61, lrate=0.300, error=28.508
# >epoch=62, lrate=0.300, error=28.499
# >epoch=63, lrate=0.300, error=28.490
# >epoch=64, lrate=0.300, error=28.482
# >epoch=65, lrate=0.300, error=28.473
# >epoch=66, lrate=0.300, error=28.463
# >epoch=67, lrate=0.300, error=28.454
# >epoch=68, lrate=0.300, error=28.445
# >epoch=69, lrate=0.300, error=28.436
# >epoch=70, lrate=0.300, error=28.426
# >epoch=71, lrate=0.300, error=28.417
# >epoch=72, lrate=0.300, error=28.407
# >epoch=73, lrate=0.300, error=28.398
# >epoch=74, lrate=0.300, error=28.388
# >epoch=75, lrate=0.300, error=28.379
# >epoch=76, lrate=0.300, error=28.369
# >epoch=77, lrate=0.300, error=28.360
# >epoch=78, lrate=0.300, error=28.351
# >epoch=79, lrate=0.300, error=28.342
# >epoch=80, lrate=0.300, error=28.333
# >epoch=81, lrate=0.300, error=28.324
# >epoch=82, lrate=0.300, error=28.315
# >epoch=83, lrate=0.300, error=28.306
# >epoch=84, lrate=0.300, error=28.297
# >epoch=85, lrate=0.300, error=28.289
# >epoch=86, lrate=0.300, error=28.280
# >epoch=87, lrate=0.300, error=28.272
# >epoch=88, lrate=0.300, error=28.264
# >epoch=89, lrate=0.300, error=28.256
# >epoch=90, lrate=0.300, error=28.248
# >epoch=91, lrate=0.300, error=28.240
# >epoch=92, lrate=0.300, error=28.232
# >epoch=93, lrate=0.300, error=28.224
# >epoch=94, lrate=0.300, error=28.217
# >epoch=95, lrate=0.300, error=28.209
# >epoch=96, lrate=0.300, error=28.202
# >epoch=97, lrate=0.300, error=28.195
# >epoch=98, lrate=0.300, error=28.188
# >epoch=99, lrate=0.300, error=28.181
# >epoch=100, lrate=0.300, error=28.174
# >epoch=101, lrate=0.300, error=28.167
# >epoch=102, lrate=0.300, error=28.160
# >epoch=103, lrate=0.300, error=28.153
# >epoch=104, lrate=0.300, error=28.147
# >epoch=105, lrate=0.300, error=28.140
# >epoch=106, lrate=0.300, error=28.134
# >epoch=107, lrate=0.300, error=28.127
# >epoch=108, lrate=0.300, error=28.121
# >epoch=109, lrate=0.300, error=28.115
# >epoch=110, lrate=0.300, error=28.108
# >epoch=111, lrate=0.300, error=28.102
# >epoch=112, lrate=0.300, error=28.096
# >epoch=113, lrate=0.300, error=28.090
# >epoch=114, lrate=0.300, error=28.084
# >epoch=115, lrate=0.300, error=28.079
# >epoch=116, lrate=0.300, error=28.073
# >epoch=117, lrate=0.300, error=28.067
# >epoch=118, lrate=0.300, error=28.061
# >epoch=119, lrate=0.300, error=28.056
# >epoch=120, lrate=0.300, error=28.050
# >epoch=121, lrate=0.300, error=28.045
# >epoch=122, lrate=0.300, error=28.039
# >epoch=123, lrate=0.300, error=28.034
# >epoch=124, lrate=0.300, error=28.028
# >epoch=125, lrate=0.300, error=28.023
# >epoch=126, lrate=0.300, error=28.018
# >epoch=127, lrate=0.300, error=28.013
# >epoch=128, lrate=0.300, error=28.008
# >epoch=129, lrate=0.300, error=28.002
# >epoch=130, lrate=0.300, error=27.997
# >epoch=131, lrate=0.300, error=27.992
# >epoch=132, lrate=0.300, error=27.987
# >epoch=133, lrate=0.300, error=27.982
# >epoch=134, lrate=0.300, error=27.978
# >epoch=135, lrate=0.300, error=27.973
# >epoch=136, lrate=0.300, error=27.968
# >epoch=137, lrate=0.300, error=27.963
# >epoch=138, lrate=0.300, error=27.958
# >epoch=139, lrate=0.300, error=27.954
# >epoch=140, lrate=0.300, error=27.949
# >epoch=141, lrate=0.300, error=27.944
# >epoch=142, lrate=0.300, error=27.940
# >epoch=143, lrate=0.300, error=27.935
# >epoch=144, lrate=0.300, error=27.931
# >epoch=145, lrate=0.300, error=27.926
# >epoch=146, lrate=0.300, error=27.922
# >epoch=147, lrate=0.300, error=27.918
# >epoch=148, lrate=0.300, error=27.913
# >epoch=149, lrate=0.300, error=27.909
# >epoch=150, lrate=0.300, error=27.905
# >epoch=151, lrate=0.300, error=27.900
# >epoch=152, lrate=0.300, error=27.896
# >epoch=153, lrate=0.300, error=27.892
# >epoch=154, lrate=0.300, error=27.888
# >epoch=155, lrate=0.300, error=27.884
# >epoch=156, lrate=0.300, error=27.880
# >epoch=157, lrate=0.300, error=27.876
# >epoch=158, lrate=0.300, error=27.872
# >epoch=159, lrate=0.300, error=27.868
# >epoch=160, lrate=0.300, error=27.864
# >epoch=161, lrate=0.300, error=27.860
# >epoch=162, lrate=0.300, error=27.856
# >epoch=163, lrate=0.300, error=27.852
# >epoch=164, lrate=0.300, error=27.848
# >epoch=165, lrate=0.300, error=27.844
# >epoch=166, lrate=0.300, error=27.841
# >epoch=167, lrate=0.300, error=27.837
# >epoch=168, lrate=0.300, error=27.833
# >epoch=169, lrate=0.300, error=27.830
# >epoch=170, lrate=0.300, error=27.826
# >epoch=171, lrate=0.300, error=27.822
# >epoch=172, lrate=0.300, error=27.819
# >epoch=173, lrate=0.300, error=27.815
# >epoch=174, lrate=0.300, error=27.811
# >epoch=175, lrate=0.300, error=27.808
# >epoch=176, lrate=0.300, error=27.804
# >epoch=177, lrate=0.300, error=27.801
# >epoch=178, lrate=0.300, error=27.797
# >epoch=179, lrate=0.300, error=27.794
# >epoch=180, lrate=0.300, error=27.790
# >epoch=181, lrate=0.300, error=27.787
# >epoch=182, lrate=0.300, error=27.784
# >epoch=183, lrate=0.300, error=27.780
# >epoch=184, lrate=0.300, error=27.777
# >epoch=185, lrate=0.300, error=27.774
# >epoch=186, lrate=0.300, error=27.770
# >epoch=187, lrate=0.300, error=27.767
# >epoch=188, lrate=0.300, error=27.764
# >epoch=189, lrate=0.300, error=27.761
# >epoch=190, lrate=0.300, error=27.757
# >epoch=191, lrate=0.300, error=27.754
# >epoch=192, lrate=0.300, error=27.751
# >epoch=193, lrate=0.300, error=27.748
# >epoch=194, lrate=0.300, error=27.745
# >epoch=195, lrate=0.300, error=27.742
# >epoch=196, lrate=0.300, error=27.739
# >epoch=197, lrate=0.300, error=27.735
# >epoch=198, lrate=0.300, error=27.732
# >epoch=199, lrate=0.300, error=27.729
# >epoch=200, lrate=0.300, error=27.726
# >epoch=201, lrate=0.300, error=27.723
# >epoch=202, lrate=0.300, error=27.720
# >epoch=203, lrate=0.300, error=27.717
# >epoch=204, lrate=0.300, error=27.714
# >epoch=205, lrate=0.300, error=27.711
# >epoch=206, lrate=0.300, error=27.708
# >epoch=207, lrate=0.300, error=27.706
# >epoch=208, lrate=0.300, error=27.703
# >epoch=209, lrate=0.300, error=27.700
# >epoch=210, lrate=0.300, error=27.697
# >epoch=211, lrate=0.300, error=27.694
# >epoch=212, lrate=0.300, error=27.691
# >epoch=213, lrate=0.300, error=27.688
# >epoch=214, lrate=0.300, error=27.686
# >epoch=215, lrate=0.300, error=27.683
# >epoch=216, lrate=0.300, error=27.680
# >epoch=217, lrate=0.300, error=27.677
# >epoch=218, lrate=0.300, error=27.675
# >epoch=219, lrate=0.300, error=27.672
# >epoch=220, lrate=0.300, error=27.669
# >epoch=221, lrate=0.300, error=27.666
# >epoch=222, lrate=0.300, error=27.664
# >epoch=223, lrate=0.300, error=27.661
# >epoch=224, lrate=0.300, error=27.658
# >epoch=225, lrate=0.300, error=27.656
# >epoch=226, lrate=0.300, error=27.653
# >epoch=227, lrate=0.300, error=27.651
# >epoch=228, lrate=0.300, error=27.648
# >epoch=229, lrate=0.300, error=27.645
# >epoch=230, lrate=0.300, error=27.643
# >epoch=231, lrate=0.300, error=27.640
# >epoch=232, lrate=0.300, error=27.638
# >epoch=233, lrate=0.300, error=27.635
# >epoch=234, lrate=0.300, error=27.633
# >epoch=235, lrate=0.300, error=27.630
# >epoch=236, lrate=0.300, error=27.627
# >epoch=237, lrate=0.300, error=27.625
# >epoch=238, lrate=0.300, error=27.622
# >epoch=239, lrate=0.300, error=27.620
# >epoch=240, lrate=0.300, error=27.618
# >epoch=241, lrate=0.300, error=27.615
# >epoch=242, lrate=0.300, error=27.613
# >epoch=243, lrate=0.300, error=27.610
# >epoch=244, lrate=0.300, error=27.608
# >epoch=245, lrate=0.300, error=27.605
# >epoch=246, lrate=0.300, error=27.603
# >epoch=247, lrate=0.300, error=27.601
# >epoch=248, lrate=0.300, error=27.598
# >epoch=249, lrate=0.300, error=27.596
# >epoch=250, lrate=0.300, error=27.593
# >epoch=251, lrate=0.300, error=27.591
# >epoch=252, lrate=0.300, error=27.589
# >epoch=253, lrate=0.300, error=27.586
# >epoch=254, lrate=0.300, error=27.584
# >epoch=255, lrate=0.300, error=27.582
# >epoch=256, lrate=0.300, error=27.579
# >epoch=257, lrate=0.300, error=27.577
# >epoch=258, lrate=0.300, error=27.575
# >epoch=259, lrate=0.300, error=27.573
# >epoch=260, lrate=0.300, error=27.570
# >epoch=261, lrate=0.300, error=27.568
# >epoch=262, lrate=0.300, error=27.566
# >epoch=263, lrate=0.300, error=27.563
# >epoch=264, lrate=0.300, error=27.561
# >epoch=265, lrate=0.300, error=27.559
# >epoch=266, lrate=0.300, error=27.557
# >epoch=267, lrate=0.300, error=27.555
# >epoch=268, lrate=0.300, error=27.552
# >epoch=269, lrate=0.300, error=27.550
# >epoch=270, lrate=0.300, error=27.548
# ...
# >epoch=81, lrate=0.300, error=26.946
# >epoch=82, lrate=0.300, error=26.937
# >epoch=83, lrate=0.300, error=26.927
# >epoch=84, lrate=0.300, error=26.918
# >epoch=85, lrate=0.300, error=26.908
# >epoch=86, lrate=0.300, error=26.899
# >epoch=87, lrate=0.300, error=26.889
# >epoch=88, lrate=0.300, error=26.880
# >epoch=89, lrate=0.300, error=26.871
# >epoch=90, lrate=0.300, error=26.862
# >epoch=91, lrate=0.300, error=26.853
# >epoch=92, lrate=0.300, error=26.845
# >epoch=93, lrate=0.300, error=26.836
# >epoch=94, lrate=0.300, error=26.827
# >epoch=95, lrate=0.300, error=26.819
# >epoch=96, lrate=0.300, error=26.810
# >epoch=97, lrate=0.300, error=26.802
# >epoch=98, lrate=0.300, error=26.794
# >epoch=99, lrate=0.300, error=26.785
# >epoch=100, lrate=0.300, error=26.777
# >epoch=101, lrate=0.300, error=26.769
# >epoch=102, lrate=0.300, error=26.761
# >epoch=103, lrate=0.300, error=26.753
# >epoch=104, lrate=0.300, error=26.745
# >epoch=105, lrate=0.300, error=26.738
# >epoch=106, lrate=0.300, error=26.730
# >epoch=107, lrate=0.300, error=26.722
# >epoch=108, lrate=0.300, error=26.715
# >epoch=109, lrate=0.300, error=26.707
# >epoch=110, lrate=0.300, error=26.700
# >epoch=111, lrate=0.300, error=26.692
# >epoch=112, lrate=0.300, error=26.685
# >epoch=113, lrate=0.300, error=26.678
# >epoch=114, lrate=0.300, error=26.671
# >epoch=115, lrate=0.300, error=26.664
# >epoch=116, lrate=0.300, error=26.657
# >epoch=117, lrate=0.300, error=26.650
# >epoch=118, lrate=0.300, error=26.643
# >epoch=119, lrate=0.300, error=26.636
# >epoch=120, lrate=0.300, error=26.629
# >epoch=121, lrate=0.300, error=26.622
# >epoch=122, lrate=0.300, error=26.616
# >epoch=123, lrate=0.300, error=26.609
# >epoch=124, lrate=0.300, error=26.602
# >epoch=125, lrate=0.300, error=26.596
# >epoch=126, lrate=0.300, error=26.589
# >epoch=127, lrate=0.300, error=26.583
# >epoch=128, lrate=0.300, error=26.577
# >epoch=129, lrate=0.300, error=26.570
# >epoch=130, lrate=0.300, error=26.564
# >epoch=131, lrate=0.300, error=26.558
# >epoch=132, lrate=0.300, error=26.552
# >epoch=133, lrate=0.300, error=26.546
# >epoch=134, lrate=0.300, error=26.540
# >epoch=135, lrate=0.300, error=26.534
# >epoch=136, lrate=0.300, error=26.528
# >epoch=137, lrate=0.300, error=26.522
# >epoch=138, lrate=0.300, error=26.516
# >epoch=139, lrate=0.300, error=26.511
# >epoch=140, lrate=0.300, error=26.505
# >epoch=141, lrate=0.300, error=26.499
# >epoch=142, lrate=0.300, error=26.493
# >epoch=143, lrate=0.300, error=26.488
# >epoch=144, lrate=0.300, error=26.482
# >epoch=145, lrate=0.300, error=26.477
# >epoch=146, lrate=0.300, error=26.471
# >epoch=147, lrate=0.300, error=26.466
# >epoch=148, lrate=0.300, error=26.461
# >epoch=149, lrate=0.300, error=26.455
# >epoch=150, lrate=0.300, error=26.450
# >epoch=151, lrate=0.300, error=26.445
# >epoch=152, lrate=0.300, error=26.440
# >epoch=153, lrate=0.300, error=26.434
# >epoch=154, lrate=0.300, error=26.429
# >epoch=155, lrate=0.300, error=26.424
# >epoch=156, lrate=0.300, error=26.419
# >epoch=157, lrate=0.300, error=26.414
# >epoch=158, lrate=0.300, error=26.409
# >epoch=159, lrate=0.300, error=26.404
# >epoch=160, lrate=0.300, error=26.399
# >epoch=161, lrate=0.300, error=26.394
# >epoch=162, lrate=0.300, error=26.389
# >epoch=163, lrate=0.300, error=26.385
# >epoch=164, lrate=0.300, error=26.380
# >epoch=165, lrate=0.300, error=26.375
# >epoch=166, lrate=0.300, error=26.370
# >epoch=167, lrate=0.300, error=26.366
# >epoch=168, lrate=0.300, error=26.361
# >epoch=169, lrate=0.300, error=26.357
# >epoch=170, lrate=0.300, error=26.352
# >epoch=171, lrate=0.300, error=26.347
# >epoch=172, lrate=0.300, error=26.343
# >epoch=173, lrate=0.300, error=26.338
# >epoch=174, lrate=0.300, error=26.334
# >epoch=175, lrate=0.300, error=26.330
# >epoch=176, lrate=0.300, error=26.325
# >epoch=177, lrate=0.300, error=26.321
# >epoch=178, lrate=0.300, error=26.316
# >epoch=179, lrate=0.300, error=26.312
# >epoch=180, lrate=0.300, error=26.308
# >epoch=181, lrate=0.300, error=26.304
# >epoch=182, lrate=0.300, error=26.299
# >epoch=183, lrate=0.300, error=26.295
# >epoch=184, lrate=0.300, error=26.291
# >epoch=185, lrate=0.300, error=26.287
# >epoch=186, lrate=0.300, error=26.283
# >epoch=187, lrate=0.300, error=26.278
# >epoch=188, lrate=0.300, error=26.274
# >epoch=189, lrate=0.300, error=26.270
# >epoch=190, lrate=0.300, error=26.266
# >epoch=191, lrate=0.300, error=26.262
# >epoch=192, lrate=0.300, error=26.258
# >epoch=193, lrate=0.300, error=26.254
# >epoch=194, lrate=0.300, error=26.250
# >epoch=195, lrate=0.300, error=26.246
# >epoch=196, lrate=0.300, error=26.243
# >epoch=197, lrate=0.300, error=26.239
# >epoch=198, lrate=0.300, error=26.235
# >epoch=199, lrate=0.300, error=26.231
# >epoch=200, lrate=0.300, error=26.227
# >epoch=201, lrate=0.300, error=26.223
# >epoch=202, lrate=0.300, error=26.220
# >epoch=203, lrate=0.300, error=26.216
# >epoch=204, lrate=0.300, error=26.212
# >epoch=205, lrate=0.300, error=26.208
# >epoch=206, lrate=0.300, error=26.205
# >epoch=207, lrate=0.300, error=26.201
# >epoch=208, lrate=0.300, error=26.197
# >epoch=209, lrate=0.300, error=26.194
# >epoch=210, lrate=0.300, error=26.190
# >epoch=211, lrate=0.300, error=26.187
# >epoch=212, lrate=0.300, error=26.183
# >epoch=213, lrate=0.300, error=26.179
# >epoch=214, lrate=0.300, error=26.176
# >epoch=215, lrate=0.300, error=26.172
# >epoch=216, lrate=0.300, error=26.169
# >epoch=217, lrate=0.300, error=26.165
# >epoch=218, lrate=0.300, error=26.162
# >epoch=219, lrate=0.300, error=26.158
# >epoch=220, lrate=0.300, error=26.155
# >epoch=221, lrate=0.300, error=26.152
# >epoch=222, lrate=0.300, error=26.148
# >epoch=223, lrate=0.300, error=26.145
# >epoch=224, lrate=0.300, error=26.141
# >epoch=225, lrate=0.300, error=26.138
# >epoch=226, lrate=0.300, error=26.135
# >epoch=227, lrate=0.300, error=26.131
# >epoch=228, lrate=0.300, error=26.128
# >epoch=229, lrate=0.300, error=26.125
# >epoch=230, lrate=0.300, error=26.122
# >epoch=231, lrate=0.300, error=26.118
# >epoch=232, lrate=0.300, error=26.115
# >epoch=233, lrate=0.300, error=26.112
# >epoch=234, lrate=0.300, error=26.109
# >epoch=235, lrate=0.300, error=26.105
# >epoch=236, lrate=0.300, error=26.102
# >epoch=237, lrate=0.300, error=26.099
# >epoch=238, lrate=0.300, error=26.096
# >epoch=239, lrate=0.300, error=26.093
# >epoch=240, lrate=0.300, error=26.090
# >epoch=241, lrate=0.300, error=26.086
# >epoch=242, lrate=0.300, error=26.083
# >epoch=243, lrate=0.300, error=26.080
# >epoch=244, lrate=0.300, error=26.077
# >epoch=245, lrate=0.300, error=26.074
# >epoch=246, lrate=0.300, error=26.071
# >epoch=247, lrate=0.300, error=26.068
# >epoch=248, lrate=0.300, error=26.065
# >epoch=249, lrate=0.300, error=26.062
# >epoch=250, lrate=0.300, error=26.059
# >epoch=251, lrate=0.300, error=26.056
# >epoch=252, lrate=0.300, error=26.053
# >epoch=253, lrate=0.300, error=26.050
# >epoch=254, lrate=0.300, error=26.047
# >epoch=255, lrate=0.300, error=26.044
# >epoch=256, lrate=0.300, error=26.041
# >epoch=257, lrate=0.300, error=26.038
# >epoch=258, lrate=0.300, error=26.035
# >epoch=259, lrate=0.300, error=26.032
# >epoch=260, lrate=0.300, error=26.030
# >epoch=261, lrate=0.300, error=26.027
# >epoch=262, lrate=0.300, error=26.024
# >epoch=263, lrate=0.300, error=26.021
# >epoch=264, lrate=0.300, error=26.018
# >epoch=265, lrate=0.300, error=26.015
# >epoch=266, lrate=0.300, error=26.013
# >epoch=267, lrate=0.300, error=26.010
# >epoch=268, lrate=0.300, error=26.007
# >epoch=269, lrate=0.300, error=26.004
# >epoch=270, lrate=0.300, error=26.001
# >epoch=271, lrate=0.300, error=25.999
# >epoch=272, lrate=0.300, error=25.996
# >epoch=273, lrate=0.300, error=25.993
# >epoch=274, lrate=0.300, error=25.990
# >epoch=275, lrate=0.300, error=25.988
# >epoch=276, lrate=0.300, error=25.985
# >epoch=277, lrate=0.300, error=25.982
# >epoch=278, lrate=0.300, error=25.980
# >epoch=279, lrate=0.300, error=25.977
# >epoch=280, lrate=0.300, error=25.974
# >epoch=281, lrate=0.300, error=25.972
# >epoch=282, lrate=0.300, error=25.969
# >epoch=283, lrate=0.300, error=25.966
# >epoch=284, lrate=0.300, error=25.964
# >epoch=285, lrate=0.300, error=25.961
# >epoch=286, lrate=0.300, error=25.959
# >epoch=287, lrate=0.300, error=25.956
# >epoch=288, lrate=0.300, error=25.953
# >epoch=289, lrate=0.300, error=25.951
# >epoch=290, lrate=0.300, error=25.948
# >epoch=291, lrate=0.300, error=25.946
# >epoch=292, lrate=0.300, error=25.943
# >epoch=293, lrate=0.300, error=25.941
# >epoch=294, lrate=0.300, error=25.938
# >epoch=295, lrate=0.300, error=25.936
# >epoch=296, lrate=0.300, error=25.933
# >epoch=297, lrate=0.300, error=25.931
# >epoch=298, lrate=0.300, error=25.928
# >epoch=299, lrate=0.300, error=25.926
# >epoch=300, lrate=0.300, error=25.923
# >epoch=301, lrate=0.300, error=25.921
# >epoch=302, lrate=0.300, error=25.918
# >epoch=303, lrate=0.300, error=25.916
# >epoch=304, lrate=0.300, error=25.913
# >epoch=305, lrate=0.300, error=25.911
# >epoch=306, lrate=0.300, error=25.909
# >epoch=307, lrate=0.300, error=25.906
# >epoch=308, lrate=0.300, error=25.904
# >epoch=309, lrate=0.300, error=25.901
# >epoch=310, lrate=0.300, error=25.899
# >epoch=311, lrate=0.300, error=25.897
# >epoch=312, lrate=0.300, error=25.894
# >epoch=313, lrate=0.300, error=25.892
# >epoch=314, lrate=0.300, error=25.890
# >epoch=315, lrate=0.300, error=25.887
# >epoch=316, lrate=0.300, error=25.885
# >epoch=317, lrate=0.300, error=25.883
# >epoch=318, lrate=0.300, error=25.880
# >epoch=319, lrate=0.300, error=25.878
# >epoch=320, lrate=0.300, error=25.876
# >epoch=321, lrate=0.300, error=25.873
# >epoch=322, lrate=0.300, error=25.871
# >epoch=323, lrate=0.300, error=25.869
# >epoch=324, lrate=0.300, error=25.867
# >epoch=325, lrate=0.300, error=25.864
# >epoch=326, lrate=0.300, error=25.862
# >epoch=327, lrate=0.300, error=25.860
# >epoch=328, lrate=0.300, error=25.858
# >epoch=329, lrate=0.300, error=25.855
# >epoch=330, lrate=0.300, error=25.853
# >epoch=331, lrate=0.300, error=25.851
# >epoch=332, lrate=0.300, error=25.849
# >epoch=333, lrate=0.300, error=25.847
# >epoch=334, lrate=0.300, error=25.844
# >epoch=335, lrate=0.300, error=25.842
# >epoch=336, lrate=0.300, error=25.840
# >epoch=337, lrate=0.300, error=25.838
# >epoch=338, lrate=0.300, error=25.836
# >epoch=339, lrate=0.300, error=25.834
# >epoch=340, lrate=0.300, error=25.831
# >epoch=341, lrate=0.300, error=25.829
# >epoch=342, lrate=0.300, error=25.827
# >epoch=343, lrate=0.300, error=25.825
# >epoch=344, lrate=0.300, error=25.823
# >epoch=345, lrate=0.300, error=25.821
# >epoch=346, lrate=0.300, error=25.819
# >epoch=347, lrate=0.300, error=25.817
# >epoch=348, lrate=0.300, error=25.815
# >epoch=349, lrate=0.300, error=25.813
# >epoch=350, lrate=0.300, error=25.810
# >epoch=351, lrate=0.300, error=25.808
# >epoch=352, lrate=0.300, error=25.806
# >epoch=353, lrate=0.300, error=25.804
# >epoch=354, lrate=0.300, error=25.802
# >epoch=355, lrate=0.300, error=25.800
# >epoch=356, lrate=0.300, error=25.798
# >epoch=357, lrate=0.300, error=25.796
# >epoch=358, lrate=0.300, error=25.794
# >epoch=359, lrate=0.300, error=25.792
# >epoch=360, lrate=0.300, error=25.790
# >epoch=361, lrate=0.300, error=25.788
# >epoch=362, lrate=0.300, error=25.786
# >epoch=363, lrate=0.300, error=25.784
# >epoch=364, lrate=0.300, error=25.782
# >epoch=365, lrate=0.300, error=25.780
# >epoch=366, lrate=0.300, error=25.778
# >epoch=367, lrate=0.300, error=25.776
# >epoch=368, lrate=0.300, error=25.774
# >epoch=369, lrate=0.300, error=25.773
# >epoch=370, lrate=0.300, error=25.771
# >epoch=371, lrate=0.300, error=25.769
# >epoch=372, lrate=0.300, error=25.767
# >epoch=373, lrate=0.300, error=25.765
# >epoch=374, lrate=0.300, error=25.763
# >epoch=375, lrate=0.300, error=25.761
# >epoch=376, lrate=0.300, error=25.759
# >epoch=377, lrate=0.300, error=25.757
# >epoch=378, lrate=0.300, error=25.755
# >epoch=379, lrate=0.300, error=25.754
# >epoch=380, lrate=0.300, error=25.752
# >epoch=381, lrate=0.300, error=25.750
# >epoch=382, lrate=0.300, error=25.748
# >epoch=383, lrate=0.300, error=25.746
# >epoch=384, lrate=0.300, error=25.744
# >epoch=385, lrate=0.300, error=25.742
# >epoch=386, lrate=0.300, error=25.741
# >epoch=387, lrate=0.300, error=25.739
# >epoch=388, lrate=0.300, error=25.737
# >epoch=389, lrate=0.300, error=25.735
# >epoch=390, lrate=0.300, error=25.733
# >epoch=391, lrate=0.300, error=25.732
# >epoch=392, lrate=0.300, error=25.730
# >epoch=393, lrate=0.300, error=25.728
# >epoch=394, lrate=0.300, error=25.726
# >epoch=395, lrate=0.300, error=25.724
# >epoch=396, lrate=0.300, error=25.723
# >epoch=397, lrate=0.300, error=25.721
# >epoch=398, lrate=0.300, error=25.719
# >epoch=399, lrate=0.300, error=25.717
# >epoch=400, lrate=0.300, error=25.716
# >epoch=401, lrate=0.300, error=25.714
# >epoch=402, lrate=0.300, error=25.712
# >epoch=403, lrate=0.300, error=25.710
# >epoch=404, lrate=0.300, error=25.709
# >epoch=405, lrate=0.300, error=25.707
# >epoch=406, lrate=0.300, error=25.705
# >epoch=407, lrate=0.300, error=25.703
# >epoch=408, lrate=0.300, error=25.702
# >epoch=409, lrate=0.300, error=25.700
# >epoch=410, lrate=0.300, error=25.698
# >epoch=411, lrate=0.300, error=25.697
# >epoch=412, lrate=0.300, error=25.695
# >epoch=413, lrate=0.300, error=25.693
# >epoch=414, lrate=0.300, error=25.692
# >epoch=415, lrate=0.300, error=25.690
# >epoch=416, lrate=0.300, error=25.688
# >epoch=417, lrate=0.300, error=25.687
# >epoch=418, lrate=0.300, error=25.685
# >epoch=419, lrate=0.300, error=25.683
# >epoch=420, lrate=0.300, error=25.682
# >epoch=421, lrate=0.300, error=25.680
# >epoch=422, lrate=0.300, error=25.678
# >epoch=423, lrate=0.300, error=25.677
# >epoch=424, lrate=0.300, error=25.675
# >epoch=425, lrate=0.300, error=25.674
# >epoch=426, lrate=0.300, error=25.672
# >epoch=427, lrate=0.300, error=25.670
# >epoch=428, lrate=0.300, error=25.669
# >epoch=429, lrate=0.300, error=25.667
# >epoch=430, lrate=0.300, error=25.666
# >epoch=431, lrate=0.300, error=25.664
# >epoch=432, lrate=0.300, error=25.662
# >epoch=433, lrate=0.300, error=25.661
# >epoch=434, lrate=0.300, error=25.659
# >epoch=435, lrate=0.300, error=25.658
# >epoch=436, lrate=0.300, error=25.656
# >epoch=437, lrate=0.300, error=25.654
# >epoch=438, lrate=0.300, error=25.653
# >epoch=439, lrate=0.300, error=25.651
# >epoch=440, lrate=0.300, error=25.650
# >epoch=441, lrate=0.300, error=25.648
# >epoch=442, lrate=0.300, error=25.647
# >epoch=443, lrate=0.300, error=25.645
# >epoch=444, lrate=0.300, error=25.644
# >epoch=445, lrate=0.300, error=25.642
# >epoch=446, lrate=0.300, error=25.641
# >epoch=447, lrate=0.300, error=25.639
# >epoch=448, lrate=0.300, error=25.638
# >epoch=449, lrate=0.300, error=25.636
# >epoch=450, lrate=0.300, error=25.635
# >epoch=451, lrate=0.300, error=25.633
# >epoch=452, lrate=0.300, error=25.632
# >epoch=453, lrate=0.300, error=25.630
# >epoch=454, lrate=0.300, error=25.629
# >epoch=455, lrate=0.300, error=25.627
# >epoch=456, lrate=0.300, error=25.626
# >epoch=457, lrate=0.300, error=25.624
# >epoch=458, lrate=0.300, error=25.623
# >epoch=459, lrate=0.300, error=25.621
# >epoch=460, lrate=0.300, error=25.620
# >epoch=461, lrate=0.300, error=25.618
# >epoch=462, lrate=0.300, error=25.617
# >epoch=463, lrate=0.300, error=25.615
# >epoch=464, lrate=0.300, error=25.614
# >epoch=465, lrate=0.300, error=25.612
# >epoch=466, lrate=0.300, error=25.611
# >epoch=467, lrate=0.300, error=25.610
# >epoch=468, lrate=0.300, error=25.608
# >epoch=469, lrate=0.300, error=25.607
# >epoch=470, lrate=0.300, error=25.605
# >epoch=471, lrate=0.300, error=25.604
# >epoch=472, lrate=0.300, error=25.602
# >epoch=473, lrate=0.300, error=25.601
# >epoch=474, lrate=0.300, error=25.600
# >epoch=475, lrate=0.300, error=25.598
# >epoch=476, lrate=0.300, error=25.597
# >epoch=477, lrate=0.300, error=25.595
# >epoch=478, lrate=0.300, error=25.594
# >epoch=479, lrate=0.300, error=25.593
# >epoch=480, lrate=0.300, error=25.591
# >epoch=481, lrate=0.300, error=25.590
# >epoch=482, lrate=0.300, error=25.589
# >epoch=483, lrate=0.300, error=25.587
# >epoch=484, lrate=0.300, error=25.586
# >epoch=485, lrate=0.300, error=25.584
# >epoch=486, lrate=0.300, error=25.583
# >epoch=487, lrate=0.300, error=25.582
# >epoch=488, lrate=0.300, error=25.580
# >epoch=489, lrate=0.300, error=25.579
# >epoch=490, lrate=0.300, error=25.578
# >epoch=491, lrate=0.300, error=25.576
# >epoch=492, lrate=0.300, error=25.575
# >epoch=493, lrate=0.300, error=25.574
# >epoch=494, lrate=0.300, error=25.572
# >epoch=495, lrate=0.300, error=25.571
# >epoch=496, lrate=0.300, error=25.570
# >epoch=497, lrate=0.300, error=25.568
# >epoch=498, lrate=0.300, error=25.567
# >epoch=499, lrate=0.300, error=25.566
# Scores: [97.5, 90.0, 80.0, 90.0, 75.0]
# Mean Accuracy: 86.500%
